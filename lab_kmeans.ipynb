# %% [markdown]
# # Welcome to lab_kmeans!
#
# In this lab, you will use the Hello Dataset to practice KMeans clustering!
#
# A few tips to remember:
#
# - Refer to your **lecture notebook** and the **pandas cheat sheet** to help you out with the code!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help! When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **ah-hah** moment!
# - We are here to help you! Don't feel embarrassed or shy to ask!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Ramya"
ca1_name = "Eliana"
ca2_name = "Vikram"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: How many finals do you have this semester?
partner1_name = "John"
partner1_netid = "jmonca3"
partner1_finals = "I have 2 in-person finals and 2 final projects to do complete."

partner2_name = ""
partner2_netid = ""
partner2_finals = ""

partner3_name = ""
partner3_netid = ""
partner3_finals = ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Returning to the Hello Dataset
#
# In the very beginning of the semester, you learned about experimental design and created the questions we would use in the "Hello Dataset".  In the very last lab of this semester, we want to come full circle with this dataset!
#
# Load the "Hello Dataset" you helped create as a DataFrame `df`!  Here's the URL again:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa22.csv
# ```

# %%
import pandas as pd

# %%
# Load the "Hello Dataset" for Fall 2022:
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa22.csv")
df
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0     CA Ana  AL1                    2.0                    5.0
# 1     CA Ram  AYR                    2.0                    5.0
# 2     CA Xin  AYO                    1.0                    5.0
# 3      Lekha  AYH                    2.0                    2.0
# 4       Reni  AYD                    2.0                    5.0
# ..       ...  ...                    ...                    ...
# 557    Emily  AYF                    2.0                    5.0
# 558  Natalia  AYM                    1.0                    3.0
# 559    Abrar  AY)                    1.0                    3.0
# 560    Chris  AYA                    1.0                    3.0
# 561     Jake  ATG                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# ...

# %% [markdown]
# ## Part 1.1: Exploring Correlation Coefficients
#
# At the beginning of the semester, you may have not known what a correlation was!  One thing we found interesting about this dataset was what data was most and least correlated!
#
# Let's find what two numeric questions where most highly correlated -- use the following cell to output the correlation matrix for the dataset:

# %%
# Display the Correlation Coefficient Matrix:
df.corr()
# Out:
#                                                     Number 1 or Number 2?  \
# Number 1 or Number 2?                                            1.000000
# Number 3 or Number 5?                                            0.113216
# At what age do you think you will die?                          -0.068453
# From 1 to 10, how happy are you right now?                      -0.058635
# How many classes are you taking this semester?                   0.012758
# How many credit hours are you taking this semes...               0.043291
# How many classes do you have on Friday?                          0.034928
# How many countries have you been to outside the...              -0.051456
# How many hours of sleep did you get last night?                  0.053226
# How many hours of sleep do you get on average?                  -0.004571
# How many meals do you have one day?                              0.030152
# How many pets do you have?                                       0.007150
# ...

# %% [markdown]
# ### Data Observation Discussion #1: Matrix Overview
#
# In the correlation coefficient matrix, the largest value that was not on the main diagonal was just `0.22201` and the lowest value was `-0.158628`.  In at least two sentences, what does this value tell us about the linear correlation of our data?

# %% [markdown]
# It tells us that the linear correlation of our data doesn't represent a strong relationship. This means that one isn't really affected by the other, or at least greatly influenced compared to other columns.

# %% [markdown]
# ### Data Observation Discussion #2: The Most Highly Correlated Data
#
# Find the two values that are most correlated.  (*Hint: Only one value is above 0.2, so it should be quick to find!*)  What two columns are most correlated in this dataset?  Does it make sense that as one of those values go up, the other one would go up -- or is this likely just result that occurred by random chance?

# %% [markdown]
# The two values that are most correlated are 'How many hours of sleep do you get on average?' and 'How many hours of sleep did you get last night?'. It makes sense that both these values go down or up with one another because if someone gets low average amounts of sleep, it is safe to assume they got low hours of sleep the previous night as well, vice versa.

# %% [markdown]
# ### Data Observation Discussion #3: Unexpected Result
#
# The correlation coefficient between `"How many classes are you taking this semester?"` and `"How many credit hours are you taking this semester?.1"` is **0.041015** (almost zero!).  This means there are almost no relationship between the number of classes you take and the number of credit hours.  In a complete sentence, explain how this makes sense!  (It seems crazy!)

# %% [markdown]
# Credit hours vary by class and you may be taking multiple classes that count for 1-3 credit hours, or a small amount of classes that count for 3-5 credit hours.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Using Clustering
#
# In our "Hello Dataset", you found that no data was highly correlated.  This exploratory data analysis (EDA) informs us that linear regression would not a good fit for a machine learning model to predict values about future DISCOVERY students.
#
# However, clustering may be a great fit!  We'll see how to create a KMeans clustering model using this dataset!  We will try and classify the class into two groups, and find out what features differentiate the two groups!
#
# To help:
# - Check out the lecture notes in your notebook, OR
# - Check out the lecture page on the DISCOVERY website: https://discovery.cs.illinois.edu/learn/Towards-Machine-Learning/Clustering/

# %% [markdown]
# ## Part 2.1: Create a KMeans Model

# %% [markdown]
# First, let's create a new KMeans model called `kmeans` that contains **just two (2) clusters**:

# %%
# Import the KMeans library:
from sklearn.cluster import KMeans

# Create a KMeans model:
kmeans = model = KMeans(n_clusters = 2)

# %% [markdown]
# ## Part 2.2: Fit the Numeric Columns to the Model
#
# The KMeans model only works on numeric data *(you can't find a mean -- or average -- of non-numbers)*.  The following code provides a list of all the numeric columns.  Run this cell store the `numeric_columns` value:

# %%
numeric_columns = ['At what age do you think you will die?', 'From 1 to 10, how happy are you right now?', 'How many classes are you taking this semester?', 'How many credit hours are you taking this semester?.1', 'How many classes do you have on Friday?', 'How many countries have you been to outside the US?', 'How many hours of sleep did you get last night?', 'How many hours of sleep do you get on average?', 'How many meals do you have one day?', 'How many pets do you have?', 'How many roommates do you have?', 'How many siblings do you have?', 'How many years do you plan to study at university?', ]
numeric_columns
# Out:
# ['At what age do you think you will die?',
#  'From 1 to 10, how happy are you right now?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking this semester?.1',
#  'How many classes do you have on Friday?',
#  'How many countries have you been to outside the US?',
#  'How many hours of sleep did you get last night?',
#  'How many hours of sleep do you get on average?',
#  'How many meals do you have one day?',
#  'How many pets do you have?',
#  'How many roommates do you have?',
#  'How many siblings do you have?',
#  'How many years do you plan to study at university?']

# %% [markdown]
# Try to `fit` the `kmeans` model data from the `numeric_columns`.
#
# **Note**: You should expect to see a `ValueError: Input X contains NaN.`!  Make sure to get that error message.

# %%
# Attempt to `fit` the `kmeans` model:
kmeans.fit(df[numeric_columns])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\13124\OneDrive\Desktop\Textbooks\Senior\Senior (1st Semester)\STAT 107\Lab\jmonca3\lab_kmeans\lab_kmeans.ipynb Cell 23 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/13124/OneDrive/Desktop/Textbooks/Senior/Senior%20%281st%20Semester%29/STAT%20107/Lab/jmonca3/lab_kmeans/lab_kmeans.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # Attempt to `fit` the `kmeans` model:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/13124/OneDrive/Desktop/Textbooks/Senior/Senior%20%281st%20Semester%29/STAT%20107/Lab/jmonca3/lab_kmeans/lab_kmeans.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> kmeans.fit(df[numeric_columns])
#
# File c:\Users\13124\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1367, in KMeans.fit(self, X, y, sample_weight)
#    1341 def fit(self, X, y=None, sample_weight=None):
# ...

# %%
#Drop rows with 'NaN' values in df
na_dropped = df[numeric_columns].dropna()

# %% [markdown]
# ## Part 2.3: Find the Rows with Missing Numeric Data Columns
#
# The error message above provides details on several solutions to dealing with missing data.  To continue to use `KMeans`, our best option is to drop rows with missing data.  Find the rows that have missing data in the `numeric_columns` and store those rows in `drops`:

# %%
drops = df[~df.index.isin(na_dropped.index)]
drops
# Out:
#             Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 46    Prof. Wade       AL1                    1.0                    5.0
# 83   Prof. Karle       AL1                    1.0                    3.0
# 114      Yuxiang       AYE                    1.0                    5.0
# 118    TA Hanjia  AYC, AYE                    1.0                    5.0
# 174      Gautham       AYG                    1.0                    3.0
# 240         Hank       AYT                    1.0                    5.0
# 321           Ji       AYQ                    1.0                    3.0
# 348       Jeslin       AYS                    2.0                    5.0
# 362        Helen       AYI                    NaN                    NaN
# 379         Evan       AYM                    1.0                    5.0
# 384     Nicholas       AYG                    1.0                    5.0
# 389        David       AYD                    1.0                    5.0
# ...

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(drops) == 19 )
assert( len(drops.index.isin(df.index)) == 19 )

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Drop the Rows with Missing Data
#
# Provided below is a snippet of code that creates a new DataFrame, `df2`, that contains only a copy of the rows that can be used for clustering:

# %%
df2 = df[ ~df.index.isin(drops.index) ].copy()
df2
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0     CA Ana  AL1                    2.0                    5.0
# 1     CA Ram  AYR                    2.0                    5.0
# 2     CA Xin  AYO                    1.0                    5.0
# 3      Lekha  AYH                    2.0                    2.0
# 4       Reni  AYD                    2.0                    5.0
# ..       ...  ...                    ...                    ...
# 557    Emily  AYF                    2.0                    5.0
# 558  Natalia  AYM                    1.0                    3.0
# 559    Abrar  AY)                    1.0                    3.0
# 560    Chris  AYA                    1.0                    3.0
# 561     Jake  ATG                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# ...

# %% [markdown]
# ## Part 2.5: Normalize the Numeric Data
#
# In lecture, you learned that means are **VERY** sensitive to outliers.  Since our data comes from different ranges, we must normalize the numeric data.  To do this, we can divide each column by the maximum value of the column, and this is done in the provided code below.
#
# Notice that, in the result, all column values are now scaled to be between 0 and 1.  Since all values are now in the same range, we no longer have any column with values in a different range.

# %%
for column in numeric_columns:
    df2[column] = df2[column] / df2[column].abs().max()
df2[numeric_columns]
# Out:
#      At what age do you think you will die?  \
# 0                                   0.10000
# 1                                   0.09375
# 2                                   0.12500
# 3                                   0.12000
# 4                                   0.04000
# ..                                      ...
# 557                                 0.11125
# 558                                 0.11250
# 559                                 0.09250
# 560                                 0.07500
# 561                                 0.09875
#
#      From 1 to 10, how happy are you right now?  \
# 0                                      0.636364
# 1                                      0.454545
# 2                                      0.909091
# 3                                      0.545455
# 4                                      0.181818
# ..                                          ...
# 557                                    0.636364
# ...

# %% [markdown]
# ## Part 2.6: Train the KMeans model with `numeric_columns` from `df2`
#
# Finally, we can train our model!  Using the `numeric_columns` and `df2`, `fit` your `kmeans` model:

# %%
kmeans.fit(df2[numeric_columns])
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# ## Part 2.7: Find the KMeans Centroids

# %% [markdown]
# In lecture, you learned that `kmeans.cluster_centers_` will display the location of the final centroids.
#
# The order they're displayed will be the same order as the columns are listed in `numeric_columns`.  Explore the centroids and numeric columns:

# %%
kmeans.cluster_centers_
# Out:
# array([[0.1107702 , 0.42975207, 0.0712387 , 0.73232323, 0.20784771,
#         0.07710438, 0.5042735 , 0.15375982, 0.42718855, 0.02810716,
#         0.05327468, 0.09890572, 0.41111111],
#        [0.10756848, 0.70658762, 0.07547674, 0.73017128, 0.19643255,
#         0.09135266, 0.58918618, 0.16398712, 0.42149758, 0.03541273,
#         0.05572698, 0.11594203, 0.41      ]])

# %%
numeric_columns
# Out:
# ['At what age do you think you will die?',
#  'From 1 to 10, how happy are you right now?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking this semester?.1',
#  'How many classes do you have on Friday?',
#  'How many countries have you been to outside the US?',
#  'How many hours of sleep did you get last night?',
#  'How many hours of sleep do you get on average?',
#  'How many meals do you have one day?',
#  'How many pets do you have?',
#  'How many roommates do you have?',
#  'How many siblings do you have?',
#  'How many years do you plan to study at university?']

# %% [markdown]
# ### Data Observation Discussion #4: Happiest Cluster
#
# In the following cell, answer all three of there questions:
# - Looking at your results above, what cluster generally will have the happier people?
# - How do you know?
# - What are the centroid values for the happiness?  (Why are they not between 1 and 10?)

# %% [markdown]
# Based on the data, it appears that cluster 1 will have the happiest people. This is because cluster one, the column has a correlation of 0.706 compared to cluster 0, which has a correlation of 0.429. This is for the column 'From 1 to 10, how happy are you right now?'

# %% [markdown]
# ## Part 2.8: Predict the Cluster for Every Data Point
#
# Using your `kmeans` model and the `numeric_columns`, `predict` the centroid for each row and store that prediction in a new column in `df2` called `cluster`:

# %%
df2["cluster"] = kmeans.predict(df2[numeric_columns])
df2
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0     CA Ana  AL1                    2.0                    5.0
# 1     CA Ram  AYR                    2.0                    5.0
# 2     CA Xin  AYO                    1.0                    5.0
# 3      Lekha  AYH                    2.0                    2.0
# 4       Reni  AYD                    2.0                    5.0
# ..       ...  ...                    ...                    ...
# 557    Emily  AYF                    2.0                    5.0
# 558  Natalia  AYM                    1.0                    3.0
# 559    Abrar  AY)                    1.0                    3.0
# 560    Chris  AYA                    1.0                    3.0
# 561     Jake  ATG                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# ...

# %% [markdown]
# ## Part 2.9: Explore the Clusters Visually
#
# In the code below, a scatter plot is used to display the two clusters in two different colors.  When using the columns `From 1 to 10, how happy are you right now?` and `How many siblings do you have?`, there are two very clean clusters divided by happiness.

# %%
df2.plot.scatter(
    x="From 1 to 10, how happy are you right now?",
    y="How many siblings do you have?",
    c="cluster", colormap="Set1"
)
# Out:
# <AxesSubplot:xlabel='From 1 to 10, how happy are you right now?', ylabel='How many siblings do you have?'>

# %% [markdown]
# ### Data Observation Discussion #5: Poor Cluster
#
# Using other `numeric_column` combinations, can you find a scatter plot where the clusters are now clean?  Modify the code below to create a graph where the are **NOT** two cleanly separated clusters among two axes.

# %%
# MODIFY THIS:
df2.plot.scatter(
    x="How many classes are you taking this semester?",
    y="How many years do you plan to study at university?",
    c="cluster", colormap="Set1"
)
# Out:
# <AxesSubplot:xlabel='How many classes are you taking this semester?', ylabel='How many years do you plan to study at university?'>

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Understanding the Challenges of Clustering
#
# You did a LOT of work clustering in this lab, but we have not truly answered the question: **What makes people in Cluster #0 different from Cluster #1?**
#
# In a job as a Data Scientist, you would dive deeper into the dataset to see if you can begin to identify trends between people in the two clusters -- what is different about people in `df2[ df2.cluster == 0 ]` vs. `df2[ df2.cluster == 1 ]`?
#
# This section does not have a correct answer -- but we want you to explore the two different clusters!  Use the cells below to look at the data in each cluster and find one possible difference between the clusters.  *This may be difficult, this is why we still need Data Scientists even when Python does the models!*

# %%
df2[df2.cluster == 0]
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 1     CA Ram  AYR                    2.0                    5.0
# 3      Lekha  AYH                    2.0                    2.0
# 4       Reni  AYD                    2.0                    5.0
# 7    Jocelyn  AYS                    1.0                    5.0
# 9     Advika  AYK                    1.0                    3.0
# ..       ...  ...                    ...                    ...
# 535   Zhiyin  AYE                    2.0                    3.0
# 539   Krithi  AYG                    1.0                    5.0
# 540   Daniel  AL1                    2.0                    5.0
# 542   weiyue  AYE                    1.0                    5.0
# 551    EDWIN  AYS                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 1                                            2-Jan                 7UP
# ...

# %%
df2[df2.cluster == 1]
# Out:
#          Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0      CA Ana  AL1                    2.0                    5.0
# 2      CA Xin  AYO                    1.0                    5.0
# 5      Linger  AYF                    2.0                    5.0
# 6    Esbeida   AYA                    2.0                    5.0
# 8     Suvinay  AYP                    1.0                    5.0
# ..        ...  ...                    ...                    ...
# 557     Emily  AYF                    2.0                    5.0
# 558   Natalia  AYM                    1.0                    3.0
# 559     Abrar  AY)                    1.0                    3.0
# 560     Chris  AYA                    1.0                    3.0
# 561      Jake  ATG                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# ...

# %% [markdown]
# ### Data Observation Discussion #5: Happiest Cluster
#
# What was one difference between the clusters?

# %% [markdown]
# There appears to be a lot of differences between each cluster. One thing I noticed is that there is a lot of people who chose 'On/After July 1' for the column 'Your Birthday is...' for cluster 1, and a lot of people who chose 'On/Before June 30' for cluster 0.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submit Your Work!
#
# You're almost done! All you need to do is to commit your lab to GitHub:
#
# 1. Make certain to save your work. To do this, go to **File -> Save all**
#
# 2. After you've saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
